# %%
import pandas as pd
import numpy as np

# %%
employee = pd.read_csv('employee_preprocessed.csv')
attendance = pd.read_csv('attendance_preprocessed.csv')
salary = pd.read_csv('salary_preprocessed.csv')
leaves = pd.read_csv('leaves_preprocessed.csv')

# %%
# join employee and attendance left join Employee_No
df = pd.merge(employee, attendance, how='left', on='Employee_No')
df.head()
# Out:
#    Employee_No  Employee_Code                 Name Title  Gender  Religion_ID  \
# 0          347              6    Myrl Bechtelar MD   Mr.    Male            1
# 1          348             33         Francis Mraz   Mr.    Male            1
# 2          349             53    Mr Emmet Blick Jr   Mr.    Male            1
# 3          351             77  Mr Nelson Braun PhD   Ms.  Female            4
# 4          352             88     Maximillian Hand   Mr.    Male            1
#
#   Marital_Status  Designation_ID Date_Joined        Date_Resigned  ...  \
# 0        Married              24  1993-12-08                   \N  ...
# 1        Married              24  1995-03-14                   \N  ...
# 2        Married              23  1988-01-27  2021-06-28 00:00:00  ...
# 3        Married              40  1999-10-01  2022-01-31 00:00:00  ...
# 4        Married               7  2001-01-26                   \N  ...
#
# ...

# %%
# merge df and salary left join Employee_No
df = pd.merge(df, salary, how='left', on='Employee_No')
df.head()
# Out:
#    Employee_No  Employee_Code                 Name Title  Gender  Religion_ID  \
# 0          347              6    Myrl Bechtelar MD   Mr.    Male            1
# 1          348             33         Francis Mraz   Mr.    Male            1
# 2          349             53    Mr Emmet Blick Jr   Mr.    Male            1
# 3          351             77  Mr Nelson Braun PhD   Ms.  Female            4
# 4          352             88     Maximillian Hand   Mr.    Male            1
#
#   Marital_Status  Designation_ID Date_Joined        Date_Resigned  ...  \
# 0        Married              24  1993-12-08                   \N  ...
# 1        Married              24  1995-03-14                   \N  ...
# 2        Married              23  1988-01-27  2021-06-28 00:00:00  ...
# 3        Married              40  1999-10-01  2022-01-31 00:00:00  ...
# 4        Married               7  2001-01-26                   \N  ...
#
# ...

# %%
#merge df and leaves left join Employee_No
df = pd.merge(df, leaves, how='left', on='Employee_No')
df.head()
# Out:
#    Employee_No  Employee_Code                 Name Title  Gender  Religion_ID  \
# 0          347              6    Myrl Bechtelar MD   Mr.    Male            1
# 1          348             33         Francis Mraz   Mr.    Male            1
# 2          349             53    Mr Emmet Blick Jr   Mr.    Male            1
# 3          351             77  Mr Nelson Braun PhD   Ms.  Female            4
# 4          352             88     Maximillian Hand   Mr.    Male            1
#
#   Marital_Status  Designation_ID Date_Joined        Date_Resigned  ...  \
# 0        Married              24  1993-12-08                   \N  ...
# 1        Married              24  1995-03-14                   \N  ...
# 2        Married              23  1988-01-27  2021-06-28 00:00:00  ...
# 3        Married              40  1999-10-01  2022-01-31 00:00:00  ...
# 4        Married               7  2001-01-26                   \N  ...
#
#    Religion         Designation Year_of_Birth onTimeIN onTimeOUT  \
# ...

# %%
df.to_csv('employee_merged.csv', index=False)
