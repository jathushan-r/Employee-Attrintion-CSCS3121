# %%
# import pandas and numpy library
import numpy as np
import pandas as pd

# %%
# read the employees.csv file
chatterbox = pd.read_csv('employees.csv')

# %%
chatterbox.head()
# Out:
#    Employee_No  Employee_Code                 Name Title  Gender  Religion_ID  \
# 0          347              6    Myrl Bechtelar MD    Mr    Male            1
# 1          348             33         Francis Mraz    Mr    Male            1
# 2          349             53    Mr Emmet Blick Jr    Mr    Male            1
# 3          351             77  Mr Nelson Braun PhD    Ms  Female            4
# 4          352             88     Maximillian Hand    Mr    Male            1
#
#   Marital_Status  Designation_ID Date_Joined Date_Resigned    Status  \
# 0        Married              24   12/8/1993            \N    Active
# 1        Married              24   3/14/1995            \N    Active
# 2        Married              23   1/27/1988     6/28/2021  Inactive
# 3        Married              40   10/1/1999     1/31/2022  Inactive
# 4        Married               7   1/26/2001            \N    Active
#
#   Inactive_Date Reporting_emp_1 Reporting_emp_2 Employment_Category  \
# 0            \N              \N              \N               Staff
# 1            \N              \N              \N               Staff
# 2     6/28/2021              \N              \N               Staff
# 3     1/31/2022              \N              \N               Staff
# 4            \N              \N              \N               Staff
#
#   Employment_Type  Religion         Designation Year_of_Birth
# 0       Permanant  Buddhist              Driver          1965
# 1       Permanant  Buddhist              Driver          1973
# 2       Permanant  Buddhist       Account Clerk          1974
# 3       Permanant  Catholic  Purchasing Officer          1974
# 4       Permanant  Buddhist        Store Keeper          1980

# %%
# data types of the columns
chatterbox.dtypes
# Out:
# Employee_No             int64
# Employee_Code           int64
# Name                   object
# Title                  object
# Gender                 object
# Religion_ID             int64
# Marital_Status         object
# Designation_ID          int64
# Date_Joined            object
# Date_Resigned          object
# Status                 object
# Inactive_Date          object
# Reporting_emp_1        object
# Reporting_emp_2        object
# Employment_Category    object
# Employment_Type        object
# Religion               object
# Designation            object
# Year_of_Birth          object
# dtype: object

# %%
# remove duplicate rows in dataframe
chatterbox.drop_duplicates(inplace=True)

# %%
# select the rows with values '0000' for Year_of_Birth and replace that with 0
chatterbox['Year_of_Birth'] = chatterbox['Year_of_Birth'].replace("'0000'", np.nan)
chatterbox[chatterbox['Year_of_Birth'].isna()]
# Out:
#      Employee_No  Employee_Code                      Name Title Gender  \
# 40           405           2034             Scottie Ratke    Mr   Male
# 44           411           2301         Jesus Dietrich Sr    Mr   Male
# 73           455           2975              Madisyn Huel    Mr   Male
# 74           456           2984             Aurelie Green    Mr   Male
# 77           461           3009  Miss Chelsie Heidenreich    Mr   Male
# ..           ...            ...                       ...   ...    ...
# 978         2615        1935042              Marge Kemmer    Mr   Male
# 979         2616        1935043      Dr Orville Schmidt V    Mr   Male
# 980         2617        1935044        Maverick Doyle DVM    Mr   Male
# 981         2637         193215                Troy Beier    Mr   Male
# 985         2705         193219           Jordon Hickle I    Mr   Male
#
#      Religion_ID Marital_Status  Designation_ID Date_Joined Date_Resigned  \
# 40             1            NaN              27    6/9/2014    0000-00-00
# 44             1        Married              24   4/28/2015    0000-00-00
# 73             3         Single              49   3/27/2017     2/19/2022
# 74             1        Married              30    1/1/2019    0000-00-00
# 77             1        Married               1    1/1/2019    0000-00-00
# ..           ...            ...             ...         ...           ...
# 978            1         Single              31   5/25/2022    0000-00-00
# 979            1         Single              31   5/25/2022    0000-00-00
# 980            1         Single              31   5/25/2022            \N
# 981            1        Married              24   6/20/2022            \N
# 985            1        Married              31   8/29/2022    0000-00-00
#
#        Status Inactive_Date Reporting_emp_1 Reporting_emp_2  \
# 40   Inactive     12/5/2019              \N              \N
# 44     Active    0000-00-00              \N              \N
# 73   Inactive     2/19/2022            1333              \N
# 74   Inactive     3/31/2020              \N              \N
# 77   Inactive      6/1/2021              \N              \N
# ..        ...           ...             ...             ...
# 978    Active    0000-00-00              \N              \N
# 979    Active    0000-00-00              \N              \N
# 980    Active            \N              \N              \N
# 981    Active            \N              \N              \N
# 985    Active    0000-00-00              \N              \N
#
#     Employment_Category Employment_Type  Religion               Designation  \
# 40                Staff  Contarct Basis  Buddhist                Supervisor
# 44                Staff  Contarct Basis  Buddhist                    Driver
# 73                Staff  Contarct Basis     Hindu  Junior Technical Officer
# 74               Labour  Contarct Basis  Buddhist        Semi Skilled Labor
# 77               Labour  Contarct Basis  Buddhist             Skilled Labor
# ..                  ...             ...       ...                       ...
# 978              Labour  Contarct Basis  Buddhist           Unskilled Labor
# 979              Labour  Contarct Basis  Buddhist           Unskilled Labor
# 980              Labour  Contarct Basis  Buddhist           Unskilled Labor
# 981              Labour  Contarct Basis  Buddhist                    Driver
# 985              Labour  Contarct Basis  Buddhist           Unskilled Labor
#
#     Year_of_Birth
# 40            NaN
# 44            NaN
# 73            NaN
# 74            NaN
# 77            NaN
# ..            ...
# 978           NaN
# 979           NaN
# 980           NaN
# 981           NaN
# 985           NaN
#
# [103 rows x 19 columns]

# %%
# change the Date_Joined column, Date_Resigned, Inactive_Date to datetime format fill suitable values for invalid dates
chatterbox['Date_Joined'] = pd.to_datetime(chatterbox['Date_Joined'], errors='coerce')
chatterbox['Date_Resigned'] = pd.to_datetime(chatterbox['Date_Resigned'], errors='coerce')
chatterbox['Inactive_Date'] = pd.to_datetime(chatterbox['Inactive_Date'], errors='coerce')
chatterbox
# Out:
# C:\Users\Jathushan\AppData\Local\Temp\ipykernel_5128\1274538752.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   chatterbox['Date_Resigned'] = pd.to_datetime(chatterbox['Date_Resigned'], errors='coerce')
# C:\Users\Jathushan\AppData\Local\Temp\ipykernel_5128\1274538752.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   chatterbox['Inactive_Date'] = pd.to_datetime(chatterbox['Inactive_Date'], errors='coerce')
#      Employee_No  Employee_Code                 Name Title  Gender  \
# 0            347              6    Myrl Bechtelar MD    Mr    Male
# 1            348             33         Francis Mraz    Mr    Male
# 2            349             53    Mr Emmet Blick Jr    Mr    Male
# 3            351             77  Mr Nelson Braun PhD    Ms  Female
# 4            352             88     Maximillian Hand    Mr    Male
# ..           ...            ...                  ...   ...     ...
# 992         2836           5434       Janis Borer Jr    Ms  Female
# 993         2890           5479        Delphia Haley    Mr    Male
# 994         2972           5480        Lance Stanton    Mr    Male
# 995         2973           5481      Chauncey Reilly    Mr    Male
# 996         3041           5482               Sudath    Mr    Male
#
#      Religion_ID Marital_Status  Designation_ID Date_Joined Date_Resigned  \
# 0              1        Married              24  1993-12-08           NaT
# 1              1        Married              24  1995-03-14           NaT
# 2              1        Married              23  1988-01-27    2021-06-28
# 3              4        Married              40  1999-10-01    2022-01-31
# 4              1        Married               7  2001-01-26           NaT
# ..           ...            ...             ...         ...           ...
# 992            1         Single              17  2022-11-01    2022-12-22
# 993            1         Single               8  2022-11-21           NaT
# 994            1         Single             201  2022-12-05           NaT
# 995            1         Single               8  2022-12-08           NaT
# 996            1        Married             104  2022-12-20           NaT
#
#        Status Inactive_Date Reporting_emp_1 Reporting_emp_2  \
# 0      Active           NaT              \N              \N
# 1      Active           NaT              \N              \N
# 2    Inactive    2021-06-28              \N              \N
# 3    Inactive    2022-01-31              \N              \N
# 4      Active           NaT              \N              \N
# ..        ...           ...             ...             ...
# 992  Inactive    2022-12-22              \N              \N
# 993    Active           NaT              \N              \N
# 994    Active           NaT              \N              \N
# 995    Active           NaT              \N              \N
# 996    Active           NaT              \N              \N
#
#     Employment_Category Employment_Type  Religion         Designation  \
# 0                 Staff       Permanant  Buddhist              Driver
# 1                 Staff       Permanant  Buddhist              Driver
# 2                 Staff       Permanant  Buddhist       Account Clerk
# 3                 Staff       Permanant  Catholic  Purchasing Officer
# 4                 Staff       Permanant  Buddhist        Store Keeper
# ..                  ...             ...       ...                 ...
# 992               Staff  Contarct Basis  Buddhist   Account Executive
# 993               Staff  Contarct Basis  Buddhist   Quantity Surveyor
# 994               Staff  Contarct Basis  Buddhist  Software Developer
# 995               Staff  Contarct Basis  Buddhist   Quantity Surveyor
# 996          Management  Contarct Basis  Buddhist          Accountant
#
#     Year_of_Birth
# 0            1965
# 1            1973
# 2            1974
# 3            1974
# 4            1980
# ..            ...
# 992          1993
# 993          1994
# 994          1997
# 995          1990
# 996          1979
#
# [997 rows x 19 columns]

# %%
# if status is active make Date_Resigned and Inactive_Date as NaT
chatterbox.loc[chatterbox['Status'] == 'Active', ['Date_Resigned', 'Inactive_Date']] = np.nan

# if Date_Resigned is NaT and Status is Inactive then fill Date_Resigned with Inactive_Date
chatterbox.loc[(chatterbox['Date_Resigned'].isna()) & (chatterbox['Status'] == 'Inactive'), 'Date_Resigned'] = chatterbox['Inactive_Date']

# %%
chatterbox.loc[chatterbox['Gender'] == 'Male', 'Title'] = 'Mr.'
chatterbox.loc[chatterbox['Gender'] == 'Female', 'Title'] = 'Ms.'

# %%
df1 = chatterbox.filter(['Gender', 'Religion_ID', 'Employment_Type', 'Designation', 'Year_of_Birth'])
df1
# Out:
#      Gender  Religion_ID Employment_Type         Designation Year_of_Birth
# 0      Male            1       Permanant              Driver          1965
# 1      Male            1       Permanant              Driver          1973
# 2      Male            1       Permanant       Account Clerk          1974
# 3    Female            4       Permanant  Purchasing Officer          1974
# 4      Male            1       Permanant        Store Keeper          1980
# ..      ...          ...             ...                 ...           ...
# 992  Female            1  Contarct Basis   Account Executive          1993
# 993    Male            1  Contarct Basis   Quantity Surveyor          1994
# 994    Male            1  Contarct Basis  Software Developer          1997
# 995    Male            1  Contarct Basis   Quantity Surveyor          1990
# 996    Male            1  Contarct Basis          Accountant          1979
#
# [997 rows x 5 columns]

# %%
# one hot encoding for df1
df1 = pd.get_dummies(df1, columns=['Gender', 'Employment_Type', 'Designation'])

# knn imputer for df1 handle missing values
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df1 = pd.DataFrame(imputer.fit_transform(df1),columns = df1.columns)
chatterbox['Year_of_Birth'] = df1['Year_of_Birth'].astype(int)

# %%
chatterbox.Marital_Status.isna().sum()
# Out:
# 67

# %%
chatterbox.columns
# Out:
# Index(['Employee_No', 'Employee_Code', 'Name', 'Title', 'Gender',
#        'Religion_ID', 'Marital_Status', 'Designation_ID', 'Date_Joined',
#        'Date_Resigned', 'Status', 'Inactive_Date', 'Reporting_emp_1',
#        'Reporting_emp_2', 'Employment_Category', 'Employment_Type', 'Religion',
#        'Designation', 'Year_of_Birth'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Subset the desired columns
df2 = chatterbox.filter(['Gender', 'Religion_ID', 'Employment_Type', 'Designation', 'Year_of_Birth', 'Marital_Status'], axis=1)

# %%
# Perform label encoding on 'Marital_Status'
le = LabelEncoder()
df2['Marital_Status'] = le.fit_transform(df2['Marital_Status'])

# replace value 2 in Marital_Status with NaN
df2['Marital_Status'] = df2['Marital_Status'].replace(2, np.nan)

# one hot encoding for df2 columns gender, employment_type, designation, status
df2 = pd.get_dummies(df2, columns=['Gender', 'Employment_Type', 'Designation'])

df2.Marital_Status.isna().sum()
# Out:
# 67

# %%
# HistGradientBoostingClassifier for df2 for handle missing values


# knn imputer for df2 handle missing values
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=1)
df2 = pd.DataFrame(imputer.fit_transform(df2),columns = df2.columns)

# replace marital status with Married if 0 else Single
df2['Marital_Status'] = df2['Marital_Status'].replace(0, 'Married')
df2['Marital_Status'] = df2['Marital_Status'].replace(1, 'Single')

# %%
chatterbox.Marital_Status = df2.Marital_Status
chatterbox.Marital_Status.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
chatterbox.isna().sum()
# Out:
# Employee_No              0
# Employee_Code            0
# Name                     0
# Title                    0
# Gender                   0
# Religion_ID              0
# Marital_Status           0
# Designation_ID           0
# Date_Joined              0
# Date_Resigned          233
# Status                   0
# Inactive_Date          233
# Reporting_emp_1          0
# Reporting_emp_2          0
# Employment_Category      0
# Employment_Type          0
# Religion                 0
# Designation              0
# Year_of_Birth            0
# dtype: int64

# %%
chatterbox.Date_Resigned.fillna('\\N', inplace=True)
chatterbox.Inactive_Date.fillna('\\N', inplace=True)

# %%
chatterbox.isna().sum()
# Out:
# Employee_No            0
# Employee_Code          0
# Name                   0
# Title                  0
# Gender                 0
# Religion_ID            0
# Marital_Status         0
# Designation_ID         0
# Date_Joined            0
# Date_Resigned          0
# Status                 0
# Inactive_Date          0
# Reporting_emp_1        0
# Reporting_emp_2        0
# Employment_Category    0
# Employment_Type        0
# Religion               0
# Designation            0
# Year_of_Birth          0
# dtype: int64

# %%
chatterbox.dtypes
# Out:
# Employee_No                     int64
# Employee_Code                   int64
# Name                           object
# Title                          object
# Gender                         object
# Religion_ID                     int64
# Marital_Status                 object
# Designation_ID                  int64
# Date_Joined            datetime64[ns]
# Date_Resigned          datetime64[ns]
# Status                         object
# Inactive_Date          datetime64[ns]
# Reporting_emp_1                object
# Reporting_emp_2                object
# Employment_Category            object
# Employment_Type                object
# Religion                       object
# Designation                    object
# Year_of_Birth                   int32
# dtype: object

# %%
chatterbox.to_csv('employee_preprocessed.csv', index=False)
